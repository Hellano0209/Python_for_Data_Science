# %% [markdown]
# # Jogo da Foca (Hangman)

# %%
import random
from os import system, name

# %% [markdown]
# ## Método main()
#
# ### 1. Cria o objeto e seleciona uma palavra aleatoriamente;
# ### 2. Enquanto o jogo não tiver terminado, print do status, solicita uma letra e faz a leitura do caractere:
# 2.1 Status do game;
#
# 2.2 Recebe input do terminal;
#
# 2.3 Verifica se aletra digitada faz parte da palavra
#
# ### 3. Verificar o status do jogo
#
# ### 4. De acodo com status, imprime mensagem na tela para o usuário
